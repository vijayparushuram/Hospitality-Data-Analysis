# %%
import pandas as pd

# %%
df_bookings = pd.read_csv("fact_bookings.csv")
df_bookings.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   27/04/2022    01/05/2022    02/05/2022
# 1  May012216558RT12        16558   30/04/2022    01/05/2022    02/05/2022
# 2  May012216558RT13        16558   28/04/2022    01/05/2022    04/05/2022
# 3  May012216558RT14        16558   28/04/2022    01/05/2022    02/05/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 0              10010             10010
# 1               9100              3640
# 2            9100000              9100
# 3               9100              3640

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot()
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.booking_platform.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.booking_platform.value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings.revenue_generated.min(), df_bookings.revenue_generated.max()
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
df_hotels = pd.read_csv("dim_hotels.csv")
df_hotels.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts()
# Out:
# city
# Mumbai       8
# Hyderabad    6
# Bangalore    6
# Delhi        5
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().sort_values()
# Out:
# city
# Delhi        5
# Hyderabad    6
# Bangalore    6
# Mumbai       8
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings[df_bookings.no_guests <=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558   27/04/2022    01/05/2022
# 3        May012216558RT14        16558   28/04/2022    01/05/2022
# 17924    May122218559RT44        18559   12/05/2022    12/05/2022
# 18020    May122218561RT22        18561   08/05/2022    12/05/2022
# 18119   May122218562RT311        18562   05/05/2022    12/05/2022
# 18121   May122218562RT313        18562   10/05/2022    12/05/2022
# 56715    Jun082218562RT12        18562   05/06/2022    08/06/2022
# 119765  Jul202219560RT220        19560   19/07/2022    20/07/2022
# 134586   Jul312217564RT47        17564   30/07/2022    31/07/2022
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0         02/05/2022       -3.0           RT1    direct online            1.0
# 3         02/05/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings=df_bookings[df_bookings.no_guests >0]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558   30/04/2022    01/05/2022
# 2        May012216558RT13        16558   28/04/2022    01/05/2022
# 4        May012216558RT15        16558   27/04/2022    01/05/2022
# 5        May012216558RT16        16558   01/05/2022    01/05/2022
# 6        May012216558RT17        16558   28/04/2022    01/05/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564   30/07/2022    31/07/2022
# 134585   Jul312217564RT46        17564   29/07/2022    31/07/2022
# 134587   Jul312217564RT48        17564   30/07/2022    31/07/2022
# 134588   Jul312217564RT49        17564   29/07/2022    31/07/2022
# 134589  Jul312217564RT410        17564   31/07/2022    31/07/2022
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1         02/05/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings=df_bookings[df_bookings.no_guests >0]
df_bookings.shape
# Out:
# (134578, 12)

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max()
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
avg, std =df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.std()
avg, std
# Out:
# (np.float64(15378.036937686695), np.float64(93040.1549314641))

# %%
avg, std
# Out:
# (np.float64(15378.036937686695), np.float64(93040.1549314641))

# %%
higher_limit = avg + 3 * std
higher_limit
# Out:
# np.float64(294498.50173207896)

# %%
lower_limit = avg - 3 * std
lower_limit
# Out:
# np.float64(-263742.4278567056)

# %%
df_bookings[df_bookings.revenue_generated < 0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings[df_bookings.revenue_generated > higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558   28/04/2022    01/05/2022
# 111      May012216559RT32        16559   29/04/2022    01/05/2022
# 315      May012216562RT22        16562   28/04/2022    01/05/2022
# 562     May012217559RT118        17559   26/04/2022    01/05/2022
# 129176   Jul282216562RT26        16562   21/07/2022    28/07/2022
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2         04/05/2022        2.0           RT1          logtrip            5.0
# 111       02/05/2022        6.0           RT3    direct online            NaN
# 315       04/05/2022        2.0           RT2   direct offline            3.0
# 562       02/05/2022        2.0           RT1           others            NaN
# 129176    29/07/2022        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings = df_bookings[df_bookings.revenue_generated < higher_limit]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558   30/04/2022    01/05/2022
# 4        May012216558RT15        16558   27/04/2022    01/05/2022
# 5        May012216558RT16        16558   01/05/2022    01/05/2022
# 6        May012216558RT17        16558   28/04/2022    01/05/2022
# 7        May012216558RT18        16558   26/04/2022    01/05/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564   30/07/2022    31/07/2022
# 134585   Jul312217564RT46        17564   29/07/2022    31/07/2022
# 134587   Jul312217564RT48        17564   30/07/2022    31/07/2022
# 134588   Jul312217564RT49        17564   29/07/2022    31/07/2022
# 134589  Jul312217564RT410        17564   31/07/2022    31/07/2022
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1         02/05/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings = df_bookings[df_bookings.revenue_generated < higher_limit]
df_bookings.shape
# Out:
# (134573, 12)

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
higher_limit = df_bookings.revenue_realized.mean() + 3 * df_bookings.revenue_realized.std()
higher_limit
# Out:
# np.float64(33479.358661845814)

# %%
df_bookings[df_bookings.revenue_realized > higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559   27/04/2022    01/05/2022
# 139      May012216559RT43        16559   01/05/2022    01/05/2022
# 143      May012216559RT47        16559   28/04/2022    01/05/2022
# 149     May012216559RT413        16559   24/04/2022    01/05/2022
# 222      May012216560RT45        16560   30/04/2022    01/05/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560   31/07/2022    31/07/2022
# 134331  Jul312219560RT412        19560   31/07/2022    31/07/2022
# 134467   Jul312219562RT45        19562   28/07/2022    31/07/2022
# 134474  Jul312219562RT412        19562   25/07/2022    31/07/2022
# 134581   Jul312217564RT42        17564   31/07/2022    31/07/2022
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137       07/05/2022        4.0           RT4           others            NaN
# ...

# %%
import pandas as pd
df_rooms  = pd.read_csv("dim_rooms.csv")
df_date = pd.read_csv("dim_date.csv")
df_aggregated = pd.read_csv("fact_aggregated_bookings.csv")

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_bookings.columns
# Out:
# Index(['booking_id', 'property_id', 'booking_date', 'check_in_date',
#        'checkout_date', 'no_guests', 'room_category', 'booking_platform',
#        'ratings_given', 'booking_status', 'revenue_generated',
#        'revenue_realized'],
#       dtype='object')

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
print(df_bookings.columns)
# Out:
# Index(['booking_id', 'property_id', 'booking_date', 'check_in_date',
#        'checkout_date', 'no_guests', 'room_category', 'booking_platform',
#        'ratings_given', 'booking_status', 'revenue_generated',
#        'revenue_realized'],
#       dtype='object')

# %%
import pandas as pd

df_bookings = pd.read_csv("fact_bookings.csv", low_memory=False)

# Clean column names
df_bookings.columns = df_bookings.columns.str.strip().str.lower()

# Check available columns
print(df_bookings.columns)

# Filter rows where room_category is RT4
df_rt4 = df_bookings[df_bookings['room_category'] == "rt4"]
print(df_rt4.head())
# Out:
# Index(['booking_id', 'property_id', 'booking_date', 'check_in_date',
#        'checkout_date', 'no_guests', 'room_category', 'booking_platform',
#        'ratings_given', 'booking_status', 'revenue_generated',
#        'revenue_realized'],
#       dtype='object')
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings[df_bookings['room_category'] == "RT4"]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 47       May012216558RT41        16558   26/04/2022    01/05/2022
# 48       May012216558RT42        16558   27/04/2022    01/05/2022
# 49       May012216558RT43        16558   29/04/2022    01/05/2022
# 137      May012216559RT41        16559   27/04/2022    01/05/2022
# 138      May012216559RT42        16559   11/04/2022    01/05/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564   29/07/2022    31/07/2022
# 134586   Jul312217564RT47        17564   30/07/2022    31/07/2022
# 134587   Jul312217564RT48        17564   30/07/2022    31/07/2022
# 134588   Jul312217564RT49        17564   29/07/2022    31/07/2022
# 134589  Jul312217564RT410        17564   31/07/2022    31/07/2022
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 47        03/05/2022        2.0           RT4          logtrip            NaN
# ...

# %%
df_bookings[df_bookings['room_category'] == "RT4"].revenue_realized.describe()
# Out:
# count    16073.000000
# mean     23440.103652
# std       9048.865206
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
23439 + 3*9048
# Out:
# 50583

# %%
df_bookings.isnull()
# Out:
#         booking_id  property_id  booking_date  check_in_date  checkout_date  \
# 0            False        False         False          False          False
# 1            False        False         False          False          False
# 2            False        False         False          False          False
# 3            False        False         False          False          False
# 4            False        False         False          False          False
# ...            ...          ...           ...            ...            ...
# 134585       False        False         False          False          False
# 134586       False        False         False          False          False
# 134587       False        False         False          False          False
# 134588       False        False         False          False          False
# 134589       False        False         False          False          False
#
# ...

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                3
# room_category            0
# booking_platform         0
# ratings_given        77907
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
#Data Transformation

# %%
df_aggregated = pd.read_csv("fact_aggregated_bookings.csv")

# %%
df_aggregated.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0

# %%
df_aggregated["occ_pct"] = df_aggregated["successful_bookings"]/df_aggregated["capacity"]

# %%
df_aggregated.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#     occ_pct
# 0  0.833333
# 1  0.933333
# 2  0.766667
# 3  1.578947
# 4  0.947368

# %%
df_aggregated["occ_pct"] = df_aggregated["occ_pct"].apply(lambda x: round(x*100, 2))
df_aggregated.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 3   157.89

# %% [markdown]
# **1. what is an average occupancy rate in each of the room categories?**

# %%
df_aggregated.groupby("room_category")["occ_pct"].mean()
# Out:
# room_category
# RT1    58.224247
# RT2    58.040278
# RT3    58.028213
# RT4    59.300461
# Name: occ_pct, dtype: float64

# %%
df_aggregated.groupby("room_category")["occ_pct"].mean().round(2)
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: occ_pct, dtype: float64

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
pd.merge(df_aggregated, df_rooms, left_on="room_category", right_on="room_id")
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occ_pct room_id    room_class
# ...

# %%
df = pd.merge(df_aggregated, df_rooms, left_on="room_category", right_on="room_id")
df.tail(4)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       occ_pct room_id    room_class
# 9196    72.22     RT4  Presidential
# 9197    50.00     RT4  Presidential
# 9198    50.00     RT4  Presidential
# 9199    75.00     RT4  Presidential

# %%
df.groupby("room_category")["occ_pct"].mean().round(2)
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: occ_pct, dtype: float64

# %%
df.groupby("room_class")["occ_pct"].mean().round(2)
# Out:
# room_class
# Elite           58.04
# Premium         58.03
# Presidential    59.30
# Standard        58.22
# Name: occ_pct, dtype: float64

# %%
df.drop("room_id", axis=1, inplace=True)
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    occ_pct room_class
# 0    83.33   Standard
# 1    93.33   Standard
# 2    76.67   Standard
# 3   157.89   Standard

# %% [markdown]
# **2.print average occupancy rate per city**

# %%
df_hotels
# Out:
#     property_id  property_name  category       city
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# ...

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df = pd.merge(df, df_hotels, on ="property_id", how="left")
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occ_pct room_class  property_name  category       city
# 0    83.33   Standard  Atliq Exotica    Luxury     Mumbai
# 1    93.33   Standard      Atliq Bay    Luxury  Bangalore
# 2    76.67   Standard   Atliq Palace  Business  Bangalore

# %%
df = pd.merge(df, df_hotels, on ="property_id")
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occ_pct room_class property_name_x category_x     city_x property_name_y  \
# 0    83.33   Standard   Atliq Exotica     Luxury     Mumbai   Atliq Exotica
# 1    93.33   Standard       Atliq Bay     Luxury  Bangalore       Atliq Bay
# 2    76.67   Standard    Atliq Palace   Business  Bangalore    Atliq Palace
#
#   category_y     city_y
# 0     Luxury     Mumbai
# 1     Luxury  Bangalore
# 2   Business  Bangalore

# %%
df.columns.tolist()
# Out:
# ['property_id',
#  'check_in_date',
#  'room_category',
#  'successful_bookings',
#  'capacity',
#  'occ_pct',
#  'room_class',
#  'property_name_x',
#  'category_x',
#  'city_x',
#  'property_name_y',
#  'category_y',
#  'city_y']

# %%
df.groupby("city_x")["occ_pct"].mean()
# Out:
# city_x
# Bangalore    56.594207
# Delhi        61.606467
# Hyderabad    58.144651
# Mumbai       57.936305
# Name: occ_pct, dtype: float64

# %%
df.groupby("city_x")["occ_pct"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='city_x'>

# %% [markdown]
# 3. **when was the occupancy better? **weekday or weekend?****

# %%
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occ_pct room_class property_name_x category_x     city_x property_name_y  \
# 0    83.33   Standard   Atliq Exotica     Luxury     Mumbai   Atliq Exotica
# 1    93.33   Standard       Atliq Bay     Luxury  Bangalore       Atliq Bay
# 2    76.67   Standard    Atliq Palace   Business  Bangalore    Atliq Palace
#
#   category_y     city_y
# 0     Luxury     Mumbai
# 1     Luxury  Bangalore
# 2   Business  Bangalore

# %%
df_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df = pd.merge(df,df_date, left_on="check_in_date",right_on="date")
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
#
#    occ_pct room_class property_name_x category_x     city_x property_name_y  \
# 0    51.72    Premium    Atliq Palace   Business  Bangalore    Atliq Palace
# 1    63.33   Standard      Atliq City   Business  Hyderabad      Atliq City
# 2    60.00   Standard       Atliq Bay     Luxury  Bangalore       Atliq Bay
#
#   category_y     city_y       date  mmm yy week no  day_type
# 0   Business  Bangalore  10-May-22  May 22    W 20  weekeday
# 1   Business  Hyderabad  10-May-22  May 22    W 20  weekeday
# 2     Luxury  Bangalore  10-May-22  May 22    W 20  weekeday

# %%
df.groupby("day_type")["occ_pct"].mean().round(2)
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: occ_pct, dtype: float64

# %% [markdown]
# **4.in the month of june, waht is the occupancy for different cities**

# %%
df["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_june_22 = df[df["mmm yy"]=="Jun 22"]
df_june_22
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        19562     10-Jun-22           RT1                   19      30.0
# 2202        19563     10-Jun-22           RT1                   17      30.0
# 2203        17558     10-Jun-22           RT1                    9      19.0
# 2204        16558     10-Jun-22           RT1                   11      19.0
# ...           ...           ...           ...                  ...       ...
# 4295        17562     30-Jun-22           RT4                    3       6.0
# 4296        19563     30-Jun-22           RT4                    3       6.0
# 4297        16560     30-Jun-22           RT4                    3       7.0
# 4298        19558     30-Jun-22           RT4                    3       7.0
# 4299        17561     30-Jun-22           RT4                    3       4.0
#
# ...

# %%
df_june_22
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        19562     10-Jun-22           RT1                   19      30.0
# 2202        19563     10-Jun-22           RT1                   17      30.0
# 2203        17558     10-Jun-22           RT1                    9      19.0
# 2204        16558     10-Jun-22           RT1                   11      19.0
# ...           ...           ...           ...                  ...       ...
# 4295        17562     30-Jun-22           RT4                    3       6.0
# 4296        19563     30-Jun-22           RT4                    3       6.0
# 4297        16560     30-Jun-22           RT4                    3       7.0
# 4298        19558     30-Jun-22           RT4                    3       7.0
# 4299        17561     30-Jun-22           RT4                    3       4.0
#
# ...

# %%
df_june_22.groupby("city_x")["occ_pct"].mean().round(2).sort_values(ascending=False)
# Out:
# city_x
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.58
# Name: occ_pct, dtype: float64

# %%
df_june_22.groupby("city_x")["occ_pct"].mean().round(2).sort_values(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='city_x'>

# %%
df_june_22.groupby("city_x")["occ_pct"].mean().round(2).sort_values(ascending=False).plot(kind="pie")
# Out:
# <Axes: ylabel='occ_pct'>

# %%
df_june_22.groupby("city_x")["occ_pct"].mean().round(2).sort_values(ascending=False).plot(kind="barh")
# Out:
# <Axes: ylabel='city_x'>

# %%
import pandas as pd

# %%
df_august = pd.read_csv("new_data_august.csv")

# %%
df_august
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
# 5        17561      Atliq Blu    Luxury     Mumbai           RT1   Standard
# 6        17564  Atliq Seasons  Business     Mumbai           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# ...

# %%
df_august.head(3)
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67

# %%
df_august.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ%'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['property_id', 'check_in_date', 'room_category', 'successful_bookings',
#        'capacity', 'occ_pct', 'room_class', 'property_name_x', 'category_x',
#        'city_x', 'property_name_y', 'category_y', 'city_y', 'date', 'mmm yy',
#        'week no', 'day_type'],
#       dtype='object')

# %%
df_august.shape
# Out:
# (7, 13)

# %%
df.shape
# Out:
# (6500, 17)

# %%
lastest_df = pd.concat([df,df_august], ignore_index=True, axis=0)
lastest_df
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           19563     10-May-22           RT3                   15      29.0
# 1           18560     10-May-22           RT1                   19      30.0
# 2           19562     10-May-22           RT1                   18      30.0
# 3           19563     10-May-22           RT1                   16      30.0
# 4           17558     10-May-22           RT1                   11      19.0
# ...           ...           ...           ...                  ...       ...
# 6502        19563     01-Aug-22           RT1                   23      30.0
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
# ...

# %%
lastest_df.shape
# Out:
# (6507, 21)

# %% [markdown]
# **6 print revenue realized per city**

# %%
df_bookings.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   27/04/2022    01/05/2022    02/05/2022
# 1  May012216558RT12        16558   30/04/2022    01/05/2022    02/05/2022
# 2  May012216558RT13        16558   28/04/2022    01/05/2022    04/05/2022
# 3  May012216558RT14        16558   28/04/2022    01/05/2022    02/05/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 0              10010             10010
# 1               9100              3640
# 2            9100000              9100
# 3               9100              3640

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df_bookings_all = pd.merge(df_bookings, df_hotels, on="property_id")
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   27/04/2022    01/05/2022    02/05/2022
# 1  May012216558RT12        16558   30/04/2022    01/05/2022    02/05/2022
# 2  May012216558RT13        16558   28/04/2022    01/05/2022    04/05/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0              10010             10010  Atliq Grands   Luxury  Delhi
# 1               9100              3640  Atliq Grands   Luxury  Delhi
# 2            9100000              9100  Atliq Grands   Luxury  Delhi

# %%
df_bookings_all.groupby("city")["revenue_realized"].sum()
# Out:
# city
# Bangalore    420397050
# Delhi        294500318
# Hyderabad    325232870
# Mumbai       668640991
# Name: revenue_realized, dtype: int64

# %% [markdown]
# 7. **print month by month revenue**

# %%
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   27/04/2022    01/05/2022    02/05/2022
# 1  May012216558RT12        16558   30/04/2022    01/05/2022    02/05/2022
# 2  May012216558RT13        16558   28/04/2022    01/05/2022    04/05/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0              10010             10010  Atliq Grands   Luxury  Delhi
# 1               9100              3640  Atliq Grands   Luxury  Delhi
# 2            9100000              9100  Atliq Grands   Luxury  Delhi

# %%
df_date["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday

# %%
pd.merge(df_bookings_all, df_date, left_on="check_in_date", right_on="date")
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized, property_name, category, city, date, mmm yy, week no, day_type]
# Index: []

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134590 entries, 0 to 134589
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134590 non-null  object
#  1   property_id        134590 non-null  int64
#  2   booking_date       134590 non-null  object
#  3   check_in_date      134590 non-null  object
#  4   checkout_date      134590 non-null  object
#  5   no_guests          134587 non-null  float64
#  6   room_category      134590 non-null  object
#  7   booking_platform   134590 non-null  object
#  8   ratings_given      56683 non-null   float64
#  9   booking_status     134590 non-null  object
#  10  revenue_generated  134590 non-null  int64
#  11  revenue_realized   134590 non-null  int64
#  12  property_name      134590 non-null  object
#  13  category           134590 non-null  object
#  14  city               134590 non-null  object
# ...

# %%
pd.to_datetime(df_date["date"])
# Out:
# C:\Users\pgkvi\AppData\Local\Temp\ipykernel_2404\3823086627.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df_date["date"])
# 0    2022-05-01
# 1    2022-05-02
# 2    2022-05-03
# 3    2022-05-04
# 4    2022-05-05
#         ...
# 87   2022-07-27
# 88   2022-07-28
# 89   2022-07-29
# 90   2022-07-30
# 91   2022-07-31
# Name: date, Length: 92, dtype: datetime64[ns]

# %%
df_date["date"] = pd.to_datetime(df_date["date"])
df_date.head(3)
# Out:
# C:\Users\pgkvi\AppData\Local\Temp\ipykernel_2404\173964601.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_date["date"] = pd.to_datetime(df_date["date"])
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     datetime64[ns]
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ KB

# %%
df_bookings_all["check_in_date"] = pd.to_datetime(
    df_bookings_all["check_in_date"],
    format="%d/%m/%Y"
)

# %%
df_bookings_all["check_in_date"] = pd.to_datetime(df_bookings_all["check_in_date"])
df_bookings_all.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   27/04/2022    2022-05-01    02/05/2022
# 1  May012216558RT12        16558   30/04/2022    2022-05-01    02/05/2022
# 2  May012216558RT13        16558   28/04/2022    2022-05-01    04/05/2022
# 3  May012216558RT14        16558   28/04/2022    2022-05-01    02/05/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city
# 0              10010             10010  Atliq Grands   Luxury  Delhi
# 1               9100              3640  Atliq Grands   Luxury  Delhi
# ...

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134590 entries, 0 to 134589
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134590 non-null  object
#  1   property_id        134590 non-null  int64
#  2   booking_date       134590 non-null  object
#  3   check_in_date      134590 non-null  datetime64[ns]
#  4   checkout_date      134590 non-null  object
#  5   no_guests          134587 non-null  float64
#  6   room_category      134590 non-null  object
#  7   booking_platform   134590 non-null  object
#  8   ratings_given      56683 non-null   float64
#  9   booking_status     134590 non-null  object
#  10  revenue_generated  134590 non-null  int64
#  11  revenue_realized   134590 non-null  int64
#  12  property_name      134590 non-null  object
#  13  category           134590 non-null  object
#  14  city               134590 non-null  object
# ...

# %%
df_bookings_all = pd.merge(df_bookings_all, df_date, left_on="check_in_date", right_on="date")
df_bookings_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   27/04/2022    2022-05-01    02/05/2022
# 1  May012216558RT12        16558   30/04/2022    2022-05-01    02/05/2022
# 2  May012216558RT13        16558   28/04/2022    2022-05-01    04/05/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0              10010             10010  Atliq Grands   Luxury  Delhi
# 1               9100              3640  Atliq Grands   Luxury  Delhi
# 2            9100000              9100  Atliq Grands   Luxury  Delhi
#
#         date  mmm yy week no day_type
# 0 2022-05-01  May 22    W 19  weekend
# ...

# %%
df_bookings_all.groupby("mmm yy")["revenue_realized"].sum()
# Out:
# mmm yy
# Jul 22    572908208
# Jun 22    553932355
# May 22    581930666
# Name: revenue_realized, dtype: int64
